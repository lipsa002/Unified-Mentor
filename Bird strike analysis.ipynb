# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_excel(r"C:\Users\91781\OneDrive\Desktop\Bird Strikes data.xlsx")

# %%
df
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# 5         236635       Airplane      WASHINGTON DULLES INTL ARPT    < 1000 ft
# 6         204371       Airplane     ORLANDO SANFORD INTL AIRPORT    < 1000 ft
# 7         201589       Airplane                ONTARIO INTL ARPT    < 1000 ft
# 8         205958       Airplane         CHICAGO O'HARE INTL ARPT    > 1000 ft
# 9         200219       Airplane               SPIRIT OF ST LOUIS    > 1000 ft
# 10        203756       Airplane     THEODORE FRANCIS GREEN STATE    < 1000 ft
# ...

# %%
df.shape
# Out:
# (20142, 25)

# %%
df.ndim
# Out:
# 2

# %%
df.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Cost: Total $  \
# count   20142.000000                    20142.000000   2.014200e+04
# mean   255993.710605                        2.861980   6.629305e+03
# std     35594.083484                       13.558744   1.360561e+05
# min    200011.000000                        1.000000   0.000000e+00
# 25%    227283.250000                        1.000000   0.000000e+00
# 50%    250426.500000                        1.000000   0.000000e+00
# 75%    270159.750000                        1.000000   0.000000e+00
# max    321909.000000                      942.000000   1.239775e+07
#
#        Feet above ground  Number of people injured
# count       20142.000000              20142.000000
# mean          795.269288                  0.001043
# std          1735.285765                  0.053188
# min             0.000000                  0.000000
# 25%             0.000000                  0.000000
# ...

# %%
df.isnull().sum()
# Out:
# Record ID                                  0
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# Pilot warned of birds or wildlife?         0
# ...

# %%
df['Remarks'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\91781\Anaconda5\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Remarks'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-ff5f29370a1b> in <module>
# ----> 1 df['Remarks'].unique()
#
# ...

# %%
df['Origin State'].unique()
# Out:
# array(['New York', 'Texas', 'Louisiana', 'Washington', 'Virginia', nan,
#        'Delaware', 'DC', 'Georgia', 'Florida', 'California', 'Illinois',
#        'Connecticut', 'Missouri', 'Rhode Island', 'Hawaii', 'Arizona',
#        'Tennessee', 'South Carolina', 'South Dakota', 'New Jersey',
#        'Colorado', 'Minnesota', 'Alabama', 'Ohio', 'Wisconsin',
#        'Michigan', 'Massachusetts', 'Alaska', 'North Carolina',
#        'Kentucky', 'Indiana', 'Oregon', 'Pennsylvania', 'New Hampshire',
#        'Arkansas', 'Nevada', 'Mississippi', 'Maryland', 'Maine', 'Quebec',
#        'Idaho', 'British Columbia', 'Utah', 'Nebraska', 'Iowa',
#        'New Mexico', 'West Virginia', 'Oklahoma', 'North Dakota',
#        'Vermont', 'Wyoming', 'Kansas', 'Prince Edward Island', 'Montana',
#        'Puerto Rico', 'Ontario', 'Virgin Islands',
#        'Newfoundland and Labrador', 'Alberta', 'Saskatchewan'],
#       dtype=object)

# %%
df['Aircraft: Type'].unique()
# Out:
# array(['Airplane', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
df.size
# Out:
# 664508

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
# Record ID                                  25558 non-null int64
# Aircraft: Type                             25429 non-null object
# Airport: Name                              25429 non-null object
# Altitude bin                               25429 non-null object
# Aircraft: Make/Model                       25558 non-null object
# Wildlife: Number struck                    25429 non-null object
# Wildlife: Number Struck Actual             25558 non-null int64
# Effect: Impact to flight                   25429 non-null object
# FlightDate                                 25429 non-null datetime64[ns]
# Effect: Indicated Damage                   25558 non-null object
# Aircraft: Number of engines?               25291 non-null object
# Aircraft: Airline/Operator                 25429 non-null object
# Origin State                               25109 non-null object
# ...

# %%
df1= df.copy()
df1
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane      DALLAS/FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# 5         236635       Airplane      WASHINGTON DULLES INTL ARPT    < 1000 ft
# 6         204371       Airplane     ORLANDO SANFORD INTL AIRPORT    < 1000 ft
# 7         201589       Airplane                ONTARIO INTL ARPT    < 1000 ft
# 8         205958       Airplane         CHICAGO O'HARE INTL ARPT    > 1000 ft
# 9         200219       Airplane               SPIRIT OF ST LOUIS    > 1000 ft
# 10        203756       Airplane     THEODORE FRANCIS GREEN STATE    < 1000 ft
# ...

# %%
df1.dropna(subset=['Aircraft: Type', 'Altitude bin','Wildlife: Number struck','Effect: Impact to flight','FlightDate','Effect: Indicated Damage','Aircraft: Number of engines?','Aircraft: Airline/Operator','Origin State','When: Phase of flight','Conditions: Precipitation','Remains of wildlife collected?','Remains of wildlife sent to Smithsonian','Wildlife: Size','Conditions: Sky','Wildlife: Species','Pilot warned of birds or wildlife?','Cost: Total $','Feet above ground','Number of people injured','Is Aircraft Large?'],inplace=True)

# %%
df1.isnull().sum()
# Out:
# Record ID                                  0
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Remarks                                    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# ...

# %%
df1.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Cost: Total $  \
# count   20142.000000                    20142.000000   2.014200e+04
# mean   255993.710605                        2.861980   6.629305e+03
# std     35594.083484                       13.558744   1.360561e+05
# min    200011.000000                        1.000000   0.000000e+00
# 25%    227283.250000                        1.000000   0.000000e+00
# 50%    250426.500000                        1.000000   0.000000e+00
# 75%    270159.750000                        1.000000   0.000000e+00
# max    321909.000000                      942.000000   1.239775e+07
#
#        Feet above ground  Number of people injured
# count       20142.000000              20142.000000
# mean          795.269288                  0.001043
# std          1735.285765                  0.053188
# min             0.000000                  0.000000
# 25%             0.000000                  0.000000
# ...

# %%
df1.isnull().sum()
# Out:
# Record ID                                  0
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# Pilot warned of birds or wildlife?         0
# ...

# %%
df1.to_excel(r"C:\Users\91781\OneDrive\Desktop\Bird Strikes data.xlsx", index= False)
